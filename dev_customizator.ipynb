# %% [markdown]
# <a href="https://colab.research.google.com/github/VBPXKSMI/Open-CYOAI-Project/blob/beta/dev_customizator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML

#-----------------------------
# --- OUTPUT CUSTOMIZATION ---
#-----------------------------
# Remove the // at the beginning of a line to use said line.
# You don't need 2 fonts, you can use the same in --font-render and --font-inputbox.
# Go here for a full help https://github.com/VBPXKSMI/Open-CYOAI-Project/wiki/Customize-the-game-render-in-Colab
display(HTML('''<style>
/* Go to https://fonts.google.com/, pick a font by clicking + icon, and copy paste the @import tab code here, minus the <style> tag.*/
@import url('');
@import url('');

/* Put google font css line value here, minus the "font-family:" */
html {
    --font-render: 'Courier New', monospace; /* change this to set your imported render font in the css */
    --font-inputbox: 'Courier New', monospace; /* change this to set your imported inputbox font in the css */
}
/* This is the main render customization. Check the /* comments to use properly */
/* hsl is Hue, Saturation, Light. Thanks to the Anon who point me that trick. */
body {    
//    background: hsl(0, 0%, 22%); /* Background color */
//    color: hsl(0, 0%, 84%); /* Text color */
//    font-size: 14px; /* Font size */
//    font-weight: 400; /* 100 to 900, by increments of 100. 400 is "normal", less is thinner, more is bolder */
//    line-height: 1.24; /* Vertical distance between lines, to simplify. */
}

/* This is the inputbox customization */
/* hsl is Hue, Saturation, Light. Thanks to the Anon who point me that trick. */
///////////* #output-area input.stdin-widget { *////////////
input.raw_input {
//    width: 90%; /* Inputbox width (relative) */
//    background: hsl(0, 0%, 22%); /* Inputbox background color */
//    border: 1px solid hsl(0, 100%, 100%); /* Inputbox borders style. See https://codepen.io/geoffgraham/pen/gxvKbQ to choose your border style */
//    border-radius: 0px 0px 0px 0px; /* Curved corners. Values are top left, top right, bottom right, bottom left. */
//    color: hsl(0, 0%, 84%); /* Inputbox text color */
//    font-size: 14px; /* Inputbox font size. Changing this also changes the inputbox height accordingly. */
//    font-weight: 400; /* 100 to 900, by increments of 100. 400 is "normal", less is thinner, more is bolder */
    font-family: var(--font-inputbox); /* Calling your inputbox font, no need to edit, just remove the first // to activate. */
}
pre {
  white-space: pre-wrap; /* Wordwrapping, no need to edit */
  font-family: var(--font-render); /* Calling your render font, no need to edit, just remove the first // to activate */
}
</style>'''))
#-----------------------------
# --- END OF CUSTOMIZATION ---
#-----------------------------

#HTML(render)
print("Lorem ipsum dolor sit amet, consectetur adipiscing elit. Etiam finibus nibh diam, quis elementum mi malesuada ac. Etiam facilisis scelerisque scelerisque. Morbi pharetra nunc ac ante pretium, sed ultricies ipsum hendrerit. Phasellus suscipit libero in dolor accumsan, aliquam congue nunc semper. Integer elit enim, laoreet in accumsan sit amet, vulputate a mi. Vestibulum facilisis posuere ante, at feugiat nunc. Vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia Curae Sed mollis elementum diam, vel scelerisque magna tempor non. Mauris consequat nulla non dolor commodo aliquet. Quisque eget ipsum sed sapien vestibulum venenatis quis vitae nisi. Proin erat ante, maximus eu viverra sit amet, viverra sit amet enim. Sed pulvinar, enim gravida posuere viverra, quam ante vestibulum elit, quis imperdiet lectus urna quis erat. Phasellus accumsan mauris neque, et ullamcorper erat semper quis. Morbi tincidunt scelerisque enim, id blandit lorem pretium eget. Nunc non metus libero. Nam consequat tempor auctor. Curabitur pretium rhoncus nisl sed suscipit. Vestibulum in dui iaculis, fringilla ante non, rutrum nisl. Duis dignissim risus et sapien pharetra, at efficitur lectus faucibus. Quisque a placerat mi. Vestibulum a purus ullamcorper quam molestie malesuada. Nam luctus neque arcu, sed vehicula elit semper non. Sed vitae neque pellentesque, ultrices odio ut, consequat mauris. Nulla facilisi. Vestibulum tempor velit ante, dictum cursus tortor commodo a. Curabitur consectetur urna nisi, in imperdiet velit convallis et. Donec vehicula congue maximus. Vestibulum ut turpis nec eros vestibulum feugiat non sed lacus. Aliquam in nisi leo. Ut rhoncus interdum condimentum. Quisque venenatis, lorem id ultrices aliquam, nunc sem vestibulum sapien, vitae volutpat sapien urna nec arcu. Quisque luctus lacus aliquam ante tristique vulputate. Nulla eleifend euismod erat, semper iaculis quam auctor eu. Nulla vehicula pulvinar risus, at cursus diam eleifend sit amet. Curabitur venenatis volutpat ex vitae efficitur. Suspendisse potenti. Nunc non magna nisl. Ut lobortis ullamcorper quam, eget ullamcorper elit consequat id. Donec ut sapien non sapien lobortis euismod. Duis vel vestibulum nisl, nec mollis mi.")
try:    
    input()
except KeyboardInterrupt:
    print('done.')
else:
    print('done.')

# %%
import ipywidgets as widgets
from ipywidgets import Box, VBox, HBox, GridBox, Button, Layout, Label, ButtonStyle
from IPython.display import display
# creating widgets
wrenderbck = widgets.ColorPicker( # render background color
    concise=True,
    description='Background:',
    value='blue',
    disabled=False
)
wrendertxt = widgets.ColorPicker( # render text color
    concise=True,
    description='Text:',
    value='blue',
    disabled=False
)
winputbck = widgets.ColorPicker( # inputbox background color
    concise=True,
    description='Background:',
    value='blue',
    disabled=False
)
winputtxt = widgets.ColorPicker( # inputbox text color
    concise=True,
    description='Text:',
    value='blue',
    disabled=False
)
wbrdclr = widgets.ColorPicker( # inputbox border color
    concise=True,
    description='Borders:',
    value='blue',
    disabled=False
)
wbodfsize = widgets.IntSlider( # render font size
    value=14,
    min=1,
    max=30,
    step=1,
    description='Font size:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
wbodfweight = widgets.IntSlider( # render font weight
    value=400,
    min=100,
    max=900,
    step=100,
    description='Font weight:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
winputwidth = widgets.IntSlider( # inputbox width
    value=90,
    min=1,
    max=100,
    step=1,
    description='Inputbox width:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
winputthik = widgets.IntSlider( # inputbox borders thickness
    value=1,
    min=1,
    max=10,
    step=1,
    description='Borders thickness:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
winputc1tl = widgets.IntSlider( # inputbox corner 1 top left
    value=0,
    min=0,
    max=1000,
    step=1,
    description='Top left:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
winputc2tr = widgets.IntSlider( # inputbox corner 2 top right
    value=0,
    min=0,
    max=1000,
    step=1,
    description='Top right:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
winputc3br = widgets.IntSlider( # inputbox corner 3 bottom right
    value=0,
    min=0,
    max=1000,
    step=1,
    description='Bottom right:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
winputc4bl = widgets.IntSlider( # inputbox corner 4 bottom left
    value=0,
    min=0,
    max=1000,
    step=1,
    description='Bottom left:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
winputfsize = widgets.IntSlider( # inputbox font size
    value=14,
    min=1,
    max=30,
    step=1,
    description='Font size:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
winputfweight = widgets.IntSlider( # inputbox font weight
    value=400,
    min=100,
    max=900,
    step=100,
    description='Font weight:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
wbodlineh = widgets.FloatSlider( # render line height
    value=1.24,
    min=0.01,
    max=10.00,
    step=0.01,
    description='Line height:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.2f',
)
winputstyle = widgets.Dropdown( # inputbox border style
    options=['none', 'ridge', 'dashed'],
    value='ridge',
    description='Borders style:',
    disabled=False,
)
wfont1url = widgets.Text( # font1 url
    value='',
    placeholder='https://fonts.googleapis.com/css?family=[FONT_NAME]&display=swap',
    description='Font URL:',
    disabled=False
)
wfont1css = widgets.Text( # font1 css
    value='',
    placeholder="'Courier New', monospace",
    description='Font CSS:',
    disabled=False
)
wfont2url = widgets.Text( #font2 url
    value='',
    placeholder='https://fonts.googleapis.com/css?family=[FONT_NAME]&display=swap',
    description='Font URL:',
    disabled=False
)
wfont2css = widgets.Text( # font 2 css
    value='',
    placeholder="'Courier New', monospace",
    description='Font CSS:',
    disabled=False
)
validate = widgets.Button( # validate button
    description='Click here to apply all settings', layout=Layout(width='auto', grid_area='accept'),
                 style=ButtonStyle(button_color='lightblue')
)
# function to assign values on validate
@validate.on_click
def validation(b):
    global renderbck
    global rendertxt
    global inputbck
    global inputtxt
    global brdclr
    global bodfsize
    global bodfweight
    global inputwidth
    global inputthik
    global inputc1tl
    global inputc2tr
    global inputc3br
    global inputc4bl
    global inputfsize
    global inputfweight
    global bodlineh
    global inputstyle
    global font1url
    global font1css
    global font2url
    global font2css
    renderbck = wrenderbck.value
    rendertxt = wrendertxt.value
    inputbck = winputbck.value
    inputtxt = winputtxt.value
    brdclr = wbrdclr.value
    bodfsize = wbodfsize.value
    bodfweight = wbodfweight.value
    inputwidth = winputwidth.value
    inputthik = winputthik.value
    inputc1tl = winputc1tl.value
    inputc2tr = winputc2tr.value
    inputc3br = winputc3br.value
    inputc4bl = winputc4bl.value
    inputfsize = winputfsize.value
    inputfweight = winputfweight.value
    bodlineh = wbodlineh.value
    inputstyle = winputstyle.value
    font1url = wfont1url.value
    font1css = wfont1css.value
    font2url = wfont2url.value
    font2css = wfont2css.value
    print(renderbck, rendertxt, inputbck, inputtxt, brdclr, bodfsize, bodfweight, inputwidth, inputthik, inputc1tl, inputc2tr, inputc3br, inputc4bl, inputfsize, inputfweight, bodlineh, inputstyle, font1url, font1css, font2url, font2css)

# basic form
headertab = Box(children=[Label("Welcome to the Customizator!")])
rendertab = VBox(children=[HBox(children=[wrenderbck,
                                     wrendertxt,]),
                      wbodfsize,
                      wbodfweight,
                      wbodlineh,
                      wfont1url,
                      wfont1css
                      ])
inputtab = VBox(children=[winputwidth,
                      winputthik,
                      winputc1tl,
                      winputc2tr,
                      winputc3br,
                      winputc4bl,
                      winputfsize,
                      winputfweight,
                      winputstyle,
                      wfont2url,
                      wfont2css,
                      HBox(children=[winputbck,
                      winputtxt]),
                      wbrdclr], grid_area='inputstuff')

header  = Button(description='Welcome to the Customizator!',
                 layout=Layout(width='auto', grid_area='header'),
                 style=ButtonStyle(button_color='lightblue'))
rendertitle = Button(description='Main Render',
                 layout=Layout(width='auto', grid_area='rendertitle'),
                 style=ButtonStyle(button_color='lightblue'))
inputtitle = Button(description='Inputbox',
                 layout=Layout(width='auto', grid_area='inputtitle'),
                 style=ButtonStyle(button_color='lightblue'))
renderstuff    = rendertab #Button(description='placeholder',
                 #layout=Layout(width='auto', grid_area='renderstuff'),
                 #style=ButtonStyle(button_color='lightblue'))
inputstuff = inputtab #Button(description='placeholder',
                 #layout=Layout(width='auto', grid_area='inputstuff'),
                 #style=ButtonStyle(button_color='lightblue'))
accept  = validate
reset = Button(description='reset',
                 layout=Layout(width='auto', grid_area='reset'),
                 style=ButtonStyle(button_color='lightblue'))

GridBox(children=[header, rendertitle, inputtitle, renderstuff, inputstuff, accept, reset],
        layout=Layout(
            width='auto',
            grid_template_rows='auto auto auto auto',
            grid_template_columns='50% 50%',
            grid_template_areas='''
            "header header"
            "rendertitle inputtitle"
            "renderstuff inputstuff"
            "accept reset"
            ''')
       )
